# %% [markdown]
# <a href="https://colab.research.google.com/github/mayank-ry/car_sale_EDA/blob/main/car_sales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import Libarires and module

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# install kaggle

# %%
# !pip install -q kaggle

# %% [markdown]
# upload kaggle.json

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-c419a11e-5344-4dcc-8757-56e3cad99fbd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c419a11e-5344-4dcc-8757-56e3cad99fbd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# make directory

# %%
# !mkdir -p ~/.kaggle

# %% [markdown]
# copy json

# %%
# !cp kaggle.json ~/.kaggle/

# %% [markdown]
# change mode

# %%
# !chmod 600 ~/.kaggle/kaggle.json

# %% [markdown]
# download dataset

# %%
# !kaggle datasets download -d msnbehdani/mock-dataset-of-second-hand-car-sales
# Out:
# Dataset URL: https://www.kaggle.com/datasets/msnbehdani/mock-dataset-of-second-hand-car-sales
# License(s): other
# ...
#   0% 0.00/489k [00:00<?, ?B/s]
# 100% 489k/489k [00:00<00:00, 993MB/s]

# %% [markdown]
# unzip the dataset

# %%
# !unzip mock-dataset-of-second-hand-car-sales.zip
# Out:
# Archive:  mock-dataset-of-second-hand-car-sales.zip
#   inflating: car_sales_data.csv

# %%
df = pd.read_csv("car_sales_data.csv")

# %%
df
# Out:
#       Manufacturer       Model  Engine size Fuel type  Year of manufacture  \
# 0             Ford      Fiesta          1.0    Petrol                 2002
# 1          Porsche  718 Cayman          4.0    Petrol                 2016
# 2             Ford      Mondeo          1.6    Diesel                 2014
# 3           Toyota        RAV4          1.8    Hybrid                 1988
# 4               VW        Polo          1.0    Petrol                 2006
# ...            ...         ...          ...       ...                  ...
# 49995          BMW          M5          5.0    Petrol                 2018
# 49996       Toyota       Prius          1.8    Hybrid                 2003
# 49997         Ford      Mondeo          1.6    Diesel                 2022
# 49998         Ford       Focus          1.0    Diesel                 2016
# 49999           VW        Golf          1.4    Diesel                 2012
#
#        Mileage   Price
# 0       127300    3074
# ...

# %% [markdown]
# 5 rows from top

# %%
df.head(5)
# Out:
#   Manufacturer       Model  Engine size Fuel type  Year of manufacture  \
# 0         Ford      Fiesta          1.0    Petrol                 2002
# 1      Porsche  718 Cayman          4.0    Petrol                 2016
# 2         Ford      Mondeo          1.6    Diesel                 2014
# 3       Toyota        RAV4          1.8    Hybrid                 1988
# 4           VW        Polo          1.0    Petrol                 2006
#
#    Mileage  Price
# 0   127300   3074
# 1    57850  49704
# 2    39190  24072
# 3   210814   1705
# 4   127869   4101

# %% [markdown]
# 5 rows from bottom

# %%
df.tail(5)
# Out:
#       Manufacturer   Model  Engine size Fuel type  Year of manufacture  \
# 49995          BMW      M5          5.0    Petrol                 2018
# 49996       Toyota   Prius          1.8    Hybrid                 2003
# 49997         Ford  Mondeo          1.6    Diesel                 2022
# 49998         Ford   Focus          1.0    Diesel                 2016
# 49999           VW    Golf          1.4    Diesel                 2012
#
#        Mileage   Price
# 49995    28664  113006
# 49996   105120    9430
# 49997     4030   49852
# 49998    26468   23630
# 49999   109300   10400

# %% [markdown]
# information of datasets

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         50000 non-null  object
#  1   Model                50000 non-null  object
#  2   Engine size          50000 non-null  float64
#  3   Fuel type            50000 non-null  object
#  4   Year of manufacture  50000 non-null  int64
#  5   Mileage              50000 non-null  int64
#  6   Price                50000 non-null  int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 2.7+ MB

# %% [markdown]
# check null values

# %%
df.isnull().sum()
# Out:
# Manufacturer           0
# Model                  0
# Engine size            0
# Fuel type              0
# Year of manufacture    0
# Mileage                0
# Price                  0
# dtype: int64

# %% [markdown]
# describe the data
# count - total non missing value
# mean - average values
# std - standard deviation (how spread your data is)
# min - minimum value
# 25% - 25% of data's value
# .
# .
# max - maximum value

# %%
df.describe()
# Out:
#         Engine size  Year of manufacture        Mileage          Price
# count  50000.000000         50000.000000   50000.000000   50000.000000
# mean       1.773058          2004.209440  112497.320700   13828.903160
# std        0.734108             9.645965   71632.515602   16416.681336
# min        1.000000          1984.000000     630.000000      76.000000
# 25%        1.400000          1996.000000   54352.250000    3060.750000
# 50%        1.600000          2004.000000  100987.500000    7971.500000
# 75%        2.000000          2012.000000  158601.000000   19026.500000
# max        5.000000          2022.000000  453537.000000  168081.000000

# %% [markdown]
# count the companies and cars that they manufactured

# %%
df["Manufacturer"].value_counts()
# Out:
# Manufacturer
# Ford       14959
# VW         14913
# Toyota     12554
# BMW         4965
# Porsche     2609
# Name: count, dtype: int64

# %% [markdown]
# changing the datatype of year of manufacturing from float to int

# %%
df['Year of manufacture'] = df['Year of manufacture'].astype(int)

# %% [markdown]
# total counts of car , manufactured year wise

# %%
df['Year of manufacture'].value_counts()
# Out:
# Year of manufacture
# 2018    1646
# 1995    1616
# 2016    1587
# 2012    1583
# 2004    1578
# 2013    1576
# 2011    1573
# 2006    1566
# 2007    1561
# 1999    1555
# 2005    1548
# 1997    1542
# 2002    1541
# 2000    1536
# 2010    1534
# 1998    1520
# 2008    1515
# 2009    1508
# 1996    1506
# 2001    1504
# 1993    1503
# 2017    1501
# 2014    1499
# 2015    1487
# 1994    1487
# 2003    1473
# 1992    1326
# 1991    1275
# 2019    1243
# 1990    1109
# 1989     920
# 2020     915
# 1988     732
# 2021     606
# 1987     605
# 1986     437
# 1985     328
# 2022     313
# 1984     146
# Name: count, dtype: int64

# %% [markdown]
# classify cars by their fuel type

# %%
df['Fuel type'].value_counts()
# Out:
# Fuel type
# Petrol    25488
# Diesel    13268
# Hybrid    11244
# Name: count, dtype: int64

# %%
df['Fuel type'].value_counts().plot(kind='pie' , autopct='%1.2f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# classification of cars on basis of engine size on bar graph

# %%
df['Engine size'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Engine size'>

# %% [markdown]
# checking price inconsitency or null values in price column

# %%
df['Price'].describe()
# Out:
# count     50000.000000
# mean      13828.903160
# std       16416.681336
# min          76.000000
# 25%        3060.750000
# 50%        7971.500000
# 75%       19026.500000
# max      168081.000000
# Name: Price, dtype: float64

# %% [markdown]
# row and columns of data

# %%
df.shape
# Out:
# (50000, 7)

# %% [markdown]
# total length i.e. number of rows in dataset

# %%
len(df)
# Out:
# 50000

# %%
df['Manufacturer'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Manufacturer'>
